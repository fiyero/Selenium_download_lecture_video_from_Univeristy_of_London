# %%
import random
#set random user agent

#everytime will return a UA from the above list
def get_random_ua():
    UA_list = [
    "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; AcooBrowser; .NET CLR 1.1.4322; .NET CLR 2.0.50727)",
    "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0; Acoo Browser; SLCC1; .NET CLR 2.0.50727; Media Center PC 5.0; .NET CLR 3.0.04506)",
    "Mozilla/4.0 (compatible; MSIE 7.0; AOL 9.5; AOLBuild 4337.35; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727)",
    "Mozilla/5.0 (Windows; U; MSIE 9.0; Windows NT 9.0; en-US)",
    "Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Win64; x64; Trident/5.0; .NET CLR 3.5.30729; .NET CLR 3.0.30729; .NET CLR 2.0.50727; Media Center PC 6.0)",
    "Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 6.0; Trident/4.0; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; .NET CLR 1.0.3705; .NET CLR 1.1.4322)",
    "Mozilla/4.0 (compatible; MSIE 7.0b; Windows NT 5.2; .NET CLR 1.1.4322; .NET CLR 2.0.50727; InfoPath.2; .NET CLR 3.0.04506.30)",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN) AppleWebKit/523.15 (KHTML, like Gecko, Safari/419.3) Arora/0.3 (Change: 287 c9dfb30)",
    "Mozilla/5.0 (X11; U; Linux; en-US) AppleWebKit/527+ (KHTML, like Gecko, Safari/419.3) Arora/0.6",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.8.1.2pre) Gecko/20070215 K-Ninja/2.1.1",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN; rv:1.9) Gecko/20080705 Firefox/3.0 Kapiko/3.0",
    "Mozilla/5.0 (X11; Linux i686; U;) Gecko/20070322 Kazehakase/0.4.5",
    "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.0.8) Gecko Fedora/1.9.0.8-1.fc10 Kazehakase/0.5.6",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.56 Safari/535.11",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_3) AppleWebKit/535.20 (KHTML, like Gecko) Chrome/19.0.1036.7 Safari/535.20",
    "Opera/9.80 (Macintosh; Intel Mac OS X 10.6.8; U; fr) Presto/2.9.168 Version/11.52",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.11 TaoBrowser/2.0 Safari/536.11",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/21.0.1180.71 Safari/537.1 LBBROWSER",
    "Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; LBBROWSER)",
    "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; QQDownload 732; .NET4.0C; .NET4.0E; LBBROWSER)",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.84 Safari/535.11 LBBROWSER",
    "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E)",
    "Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; QQBrowser/7.0.3698.400)",
    "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; QQDownload 732; .NET4.0C; .NET4.0E)",
    "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Trident/4.0; SV1; QQDownload 732; .NET4.0C; .NET4.0E; 360SE)",
    "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; QQDownload 732; .NET4.0C; .NET4.0E)",
    "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E)",
    "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/21.0.1180.89 Safari/537.1",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/21.0.1180.89 Safari/537.1",
    "Mozilla/5.0 (iPad; U; CPU OS 4_2_1 like Mac OS X; zh-cn) AppleWebKit/533.17.9 (KHTML, like Gecko) Version/5.0.2 Mobile/8C148 Safari/6533.18.5",
    "Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:2.0b13pre) Gecko/20110307 Firefox/4.0b13pre",
    "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:16.0) Gecko/20100101 Firefox/16.0",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11",
    "Mozilla/5.0 (X11; U; Linux x86_64; zh-CN; rv:1.9.2.10) Gecko/20100922 Ubuntu/10.10 (maverick) Firefox/3.6.10",
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
    'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:57.0) Gecko/20100101 Firefox/57.0'
    ]

    user_agent = random.choice(UA_list)
    header = {'User-Agent':user_agent}
    
    return header

# %%
#Selenium to crawd
import requests
from bs4 import BeautifulSoup
import re
from selenium import webdriver

#if you failed to set PATH, have to put the path of the chromedriver inside the ()
driver=webdriver.Chrome('D:/Google/Learning/chromedriver.exe')
driver.get("https://learn.london.ac.uk/login/index.php")

username=driver.find_element_by_id("username")
#username.clear() #incase there maybe already filled pw
password=driver.find_element_by_id("password")

username.send_keys("USER_NAME")
password.send_keys("PW")

driver.find_element_by_id("loginbtn").click()
#time.sleep(2)

#by experiemnt actually we can get all link in sub_topic so just skip into it
driver.get("https://learn.london.ac.uk/course/view.php?id=143&section=3")

#get html content
sub_topic=driver.page_source

# %%
#turn into beautiful soup obj for later use
sub_topic_content=BeautifulSoup(sub_topic,'lxml')

# %%
subcontent_link= [i.a['href'] for i in sub_topic_content.find_all(class_='progressEventInfo')]
subcontent_link
# Out:
# ['#',
#  'https://learn.london.ac.uk/mod/forum/view.php?id=4299',
#  'https://learn.london.ac.uk/mod/resource/view.php?id=4660',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=3452',
#  'https://learn.london.ac.uk/mod/page/view.php?id=5563',
#  'https://learn.london.ac.uk/mod/page/view.php?id=5564',
#  'https://learn.london.ac.uk/mod/page/view.php?id=5565',
#  'https://learn.london.ac.uk/mod/page/view.php?id=5566',
#  'https://learn.london.ac.uk/mod/page/view.php?id=5567',
#  'https://learn.london.ac.uk/mod/page/view.php?id=5568',
#  'https://learn.london.ac.uk/mod/turnitintooltwo/view.php?id=4698',
#  'https://learn.london.ac.uk/mod/resource/view.php?id=4869',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3012',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=3172',
#  'https://learn.london.ac.uk/mod/resource/view.php?id=3187',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=3286',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3013',
#  'https://learn.london.ac.uk/mod/resource/view.php?id=3186',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=3321',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3014',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=3322',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3015',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=3323',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3017',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=3368',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3019',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=3370',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3021',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=3394',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3023',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3024',
#  'https://learn.london.ac.uk/mod/questionnaire/view.php?id=3026',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3030',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=3501',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3032',
#  'https://learn.london.ac.uk/mod/resource/view.php?id=4268',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3033',
#  'https://learn.london.ac.uk/mod/resource/view.php?id=4259',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=4275',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=4273',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3035',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=4258',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3036',
#  'https://learn.london.ac.uk/mod/resource/view.php?id=4272',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=4276',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3038',
#  'https://learn.london.ac.uk/mod/questionnaire/view.php?id=3040',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3042',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3044',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=4323',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3045',
#  'https://learn.london.ac.uk/mod/resource/view.php?id=4339',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=4340',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3046',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=4344',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3048',
#  'https://learn.london.ac.uk/mod/scorm/view.php?id=3047',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3049',
#  'https://learn.london.ac.uk/mod/questionnaire/view.php?id=3051',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3053',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3055',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3056',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4261',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4262',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3059',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3057',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3058',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4263',
#  'https://learn.london.ac.uk/mod/page/view.php?id=4250',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4264',
#  'https://learn.london.ac.uk/mod/questionnaire/view.php?id=3067',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3069',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3071',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3072',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4265',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3073',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4266',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3074',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4267',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3080',
#  'https://learn.london.ac.uk/mod/questionnaire/view.php?id=3083',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3086',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3087',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3088',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4392',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3089',
#  'https://learn.london.ac.uk/mod/page/view.php?id=5559',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4393',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3090',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3091',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4394',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3092',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4395',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3093',
#  'https://learn.london.ac.uk/mod/resource/view.php?id=4658',
#  'https://learn.london.ac.uk/mod/questionnaire/view.php?id=3098',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3101',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3102',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3103',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4396',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3104',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4398',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3105',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4399',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3107',
#  'https://learn.london.ac.uk/mod/questionnaire/view.php?id=3111',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3115',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3116',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4400',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3117',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4401',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4404',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3113',
#  'https://learn.london.ac.uk/mod/questionnaire/view.php?id=3125',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4413',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3143',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4415',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4414',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3145',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4416',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3146',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4417',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3148',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4418',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3140',
#  'https://learn.london.ac.uk/mod/questionnaire/view.php?id=3152',
#  'https://learn.london.ac.uk/mod/resource/view.php?id=5759',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3129',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3130',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4406',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3131',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3132',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4408',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3133',
#  'https://learn.london.ac.uk/mod/quiz/view.php?id=4409',
#  'https://learn.london.ac.uk/mod/page/view.php?id=5508',
#  'https://learn.london.ac.uk/mod/page/view.php?id=3127',
#  'https://learn.london.ac.uk/mod/questionnaire/view.php?id=3137']

# %%
subcontent_title= [i.a.text for i in sub_topic_content.find_all(class_='progressEventInfo')]
subcontent_title
# Out:
# ['Show all info',
#  'Online Tutor Forum',
#  'Data Science April 2020 Timetable',
#  'Information skills tutorial',
#  'Module Description ',
#  'Module goals and objectives',
#  'Textbook and Readings',
#  'Module outline',
#  'Activities of this module',
#  'How to pass this module',
#  'Mathematics &amp; Statistics - CW1',
#  'Coursework 1 Brief',
#  '1.3 Mini lecture – 1',
#  '1.4 Quiz: graphs of derivatives',
#  '1.5 Differentiating polynomials',
#  '1.6 Derivatives of polynomials',
#  '1.7 Mini lecture – 2',
#  '1.8 Answer to minimisation problem',
#  '1.9 Max min quiz',
#  '1.10 Mini lecture – 3',
#  '1.11 Special functions quiz',
#  '1.12 Mini lecture – 4',
#  '1.13 Product rule quiz 1',
#  '1.14 Mini lecture – 5',
#  '1.15 Chain rule quiz',
#  '1.16 Mini lecture – 6',
#  '1.17 Quotiet rule quiz',
#  '1.18 Mini lecture – 7',
#  '1.19 Max min quiz',
#  '1.20 Information retrieval activity',
#  '1.21 Essential reading',
#  '1.23 Feedback',
#  '2.3 Mini lecture – 1',
#  '2.4 Dot product quiz',
#  '2.5 Mini lecture – 2',
#  '2.6 Mutiplying matrices note',
#  '2.7 Mini lecture – 3',
#  '2.8 System of equations example',
#  '2.9 Gaussian elimination quiz',
#  '2.10 Optional further exercises',
#  '2.11 Mini lecture – 4',
#  '2.12 Matrix multiplication quiz',
#  '2.13 Mini lecture – 5',
#  '2.14 Matrix inversion note',
#  '2.15 Matrix inversion quiz',
#  '2.16 Essential reading',
#  '2.18 Feedback',
#  '3.1 Introduction',
#  '3.3 Mini lecture – 1',
#  '3.4 Linear transformation quiz',
#  '3.5 Mini lecture – 2',
#  '3.6 Note on kernels',
#  '3.7 Kernel quiz',
#  '3.8 Mini lecture – 3',
#  '3.9 Partial derivatives quiz',
#  '3.10 Mini lecture – 4',
#  '3.11 Partial derivatives and stationary points quiz',
#  '3.12 Essential reading',
#  '3.14 Feedback',
#  '4.1 Introduction',
#  '4.3 Mini lecture – 1',
#  '4.4 Mini lecture – 2',
#  '4.5 Quiz on types of data and scales of measurement',
#  '4.8 Quiz on tabular and graphical presentation of data',
#  '4.9 Essential reading',
#  '4.10 Mini lecture – 5',
#  '4.12 Mini lecture – 6',
#  '4.13 Quiz on measures of location and variability',
#  '4.15 Mini lecture - 7',
#  '4.16 Quiz on shape of a distribution and detecting outliers',
#  '4.19 Feedback',
#  '5.1 Introduction',
#  '5.3 Mini lecture – 1',
#  '5.4 Mini lecture – 2',
#  '5.5 Quiz on probability theory and counting techniques',
#  '5.6 Mini lecture – 3',
#  '5.7 Quiz on conditional probability',
#  '5.8 Mini lecture – 4',
#  "5.9 Quiz on Bayes' theorem",
#  '5.10 Essential reading',
#  '5.12 Feedback',
#  '6.0 Introduction',
#  '6.1 Mini lecture – 1',
#  '6.2 Mini lecture – 2',
#  '6.3 Quiz on random variables and discrete probability distributions',
#  '6.4 Mini lecture – 3',
#  '6.5 Mini lecture – 4',
#  '6.6 Quiz on binomial and Poisson distributions',
#  '6.7 Mini lecture – 5',
#  '6.8 Mini lecture – 6',
#  '6.9 Quiz on the normal distribution',
#  '6.10 Mini lecture – 7',
#  '6.11 Quiz on the exponential and gamma distributions',
#  '6.14 Essential reading',
#  '6.16 Notes on probability distributions',
#  '6.18 Topic 6 Feedback',
#  '7.0 Introduction',
#  '7.1 Mini lecture – 1',
#  '7.2 Mini lecture – 2',
#  '7.3 Quiz on sample mean distribution and central limit theorem',
#  '7.4 Mini lecture – 3',
#  '7.5 Quiz on sampling distribution of sample proportion',
#  '7.6 Mini lecture – 4',
#  '7.7 Quiz on sampling distributions related to the normal distribution',
#  '7.9 Essential reading',
#  '7.12 Topic 7 Feedback',
#  '8.0 Introduction',
#  '8.1 Mini lecture – 1',
#  '8.2 Quiz on developing null and alternative hypotheses',
#  '8.3 Mini lecture – 2',
#  '8.4 Quiz on type I and type II errors',
#  '8.10 Quiz on tests involving population differences',
#  '8.12 Essential reading',
#  '8.15 Topic 8 Feedback',
#  '9.1 Quiz on introduction to correlation',
#  '9.2 Mini lecture – 1',
#  '9.3 Quiz on introduction to linear regression',
#  '9.5 Quiz on linear regression model',
#  '9.6 Mini lecture – 3',
#  '9.7 Quiz on method of least squares',
#  '9.8 Mini lecture – 4',
#  '9.9 Quiz on coefficient of determination',
#  '9.10 Mini lecture – 6',
#  '9.11 Quiz on correlation',
#  '9.13 Essential reading',
#  '9.15 Topic 9 Feedback',
#  'Important Announcement. Topic 10 is optional!',
#  '10.0 Introduction',
#  '10.1 Mini lecture – 1',
#  '10.2 Quiz on one-way ANOVA',
#  '10.3 Mini lecture – 2',
#  '10.4 Mini lecture – 3',
#  '10.5 Quiz on two-way ANOVA',
#  '10.7 Mini lecture – 4',
#  '10.8 Quiz on testing hypothesis for main effects and interaction',
#  '10.9 Mini lecture - 5',
#  '10.10 Essential reading',
#  '10.13 Topic 10 Feedback']

# %%
pattern=r'(BASE)(.+)(\.rss)'

#given condition, only get video of certain title
for k,v in zip (subcontent_title,subcontent_link):
    if 'lecture' in k or 'summary' in k or 'webinar' in k:
        #if 'lecture' or 'summary' or 'webinar' in k: is wrong
        driver.get(str(v))
        #InvalidArgumentException: Message: invalid argument 
        #need to string the v
        
        lecture_content=driver.page_source
        lecture_content=BeautifulSoup(lecture_content,'lxml')
        
        video_link=re.search(pattern,lecture_content.text).group(0)        
        #clean and edit the link
        video_link=video_link.replace('rss','mp4')
        video_link='http://'+video_link[:-4]+'_1080.mp4'
        
        #download the video
        lecture_video = requests.get(video_link,headers=get_random_ua()) 
        with open(f'{k}.mp4','wb') as f:
            f.write(lecture_video.content)
            lecture_video.close() 
        print(f'{k} is downloaded')
        
print('Job is done!')
# Out:
# 1.3 Mini lecture – 1 is downloaded
# 1.7 Mini lecture – 2 is downloaded
# 1.10 Mini lecture – 3 is downloaded
# 1.12 Mini lecture – 4 is downloaded
# 1.14 Mini lecture – 5 is downloaded
# 1.16 Mini lecture – 6 is downloaded
# 1.18 Mini lecture – 7 is downloaded
# 2.3 Mini lecture – 1 is downloaded
# 2.5 Mini lecture – 2 is downloaded
# 2.7 Mini lecture – 3 is downloaded
# 2.11 Mini lecture – 4 is downloaded
# 2.13 Mini lecture – 5 is downloaded
# 3.3 Mini lecture – 1 is downloaded
# 3.5 Mini lecture – 2 is downloaded
# 3.8 Mini lecture – 3 is downloaded
# 3.10 Mini lecture – 4 is downloaded
# 4.3 Mini lecture – 1 is downloaded
# 4.4 Mini lecture – 2 is downloaded
# 4.10 Mini lecture – 5 is downloaded
# 4.12 Mini lecture – 6 is downloaded
# 4.15 Mini lecture - 7 is downloaded
# 5.3 Mini lecture – 1 is downloaded
# 5.4 Mini lecture – 2 is downloaded
# 5.6 Mini lecture – 3 is downloaded
# 5.8 Mini lecture – 4 is downloaded
# 6.1 Mini lecture – 1 is downloaded
# 6.2 Mini lecture – 2 is downloaded
# 6.4 Mini lecture – 3 is downloaded
# 6.5 Mini lecture – 4 is downloaded
# 6.7 Mini lecture – 5 is downloaded
# 6.8 Mini lecture – 6 is downloaded
# 6.10 Mini lecture – 7 is downloaded
# 7.1 Mini lecture – 1 is downloaded
# 7.2 Mini lecture – 2 is downloaded
# 7.4 Mini lecture – 3 is downloaded
# 7.6 Mini lecture – 4 is downloaded
# 8.1 Mini lecture – 1 is downloaded
# 8.3 Mini lecture – 2 is downloaded
# 9.2 Mini lecture – 1 is downloaded
# 9.6 Mini lecture – 3 is downloaded
# 9.8 Mini lecture – 4 is downloaded
# 9.10 Mini lecture – 6 is downloaded
# 10.1 Mini lecture – 1 is downloaded
# 10.3 Mini lecture – 2 is downloaded
# 10.4 Mini lecture – 3 is downloaded
# 10.7 Mini lecture – 4 is downloaded
# 10.9 Mini lecture - 5 is downloaded
# Job is done!

# %%
import requests
from bs4 import BeautifulSoup
import re
from selenium import webdriver

def get_video(login,pw,url,video_base):
    #if you failed to set PATH, have to put the path of the chromedriver inside the ()
    driver=webdriver.Chrome('D:/Google/Learning/chromedriver.exe')
    driver.get("https://learn.london.ac.uk/login/index.php")

    username=driver.find_element_by_id("username")
    #username.clear() #incase there maybe already filled pw
    password=driver.find_element_by_id("password")

    username.send_keys(login)
    password.send_keys(pw)

    driver.find_element_by_id("loginbtn").click()
    #time.sleep(2)

    #by experiemnt actually we can get all link in sub_topic so just skip into it
    driver.get(url)

    #get html content
    sub_topic=driver.page_source
    
    
    #turn into beautiful soup obj for later use
    sub_topic_content=BeautifulSoup(sub_topic,'lxml')
    subcontent_link= [i.a['href'] for i in sub_topic_content.find_all(class_='progressEventInfo')]
    subcontent_title= [i.a.text for i in sub_topic_content.find_all(class_='progressEventInfo')]
    
    
    pattern=f'({video_base})(.+)(\.rss)'

    #given condition, only get video of certain title
    for k,v in zip (subcontent_title,subcontent_link):
        if 'lecture' in k or 'summary' in k or 'webinar' in k:
            #if 'lecture' or 'summary' or 'webinar' in k: is wrong
            driver.get(str(v))
            #InvalidArgumentException: Message: invalid argument 
            #need to string the v

            lecture_content=driver.page_source
            lecture_content=BeautifulSoup(lecture_content,'lxml')

            video_link=re.search(pattern,lecture_content.text).group(0)        
            #clean and edit the link
            video_link=video_link.replace('rss','mp4')
            video_link='http://'+video_link[:-4]+'_1080.mp4'

            #download the video
            lecture_video = requests.get(video_link,headers=get_random_ua()) 
            with open(f'{k}.mp4','wb') as f:
                f.write(lecture_video.content)
                lecture_video.close() 
            print(f'{k} is downloaded')

    print('Job is done!')

# %%
login=''
pw=''
url='https://learn.london.ac.uk/course/view.php?id=142&section=4'
video_base=''

get_video(login,pw,url,video_base)
# Out:
# 1.4 Mini lecture – 1 is downloaded
# 1.6 Mini lecture – 2 is downloaded
# 1.9 Mini lecture – 3 is downloaded
# 1.11 Mini lecture – 4 is downloaded
# 1.12 Mini lecture – 5 is downloaded
# 1.13 Mini lecture – 6 is downloaded
# 1.14 Mini lecture – 7 is downloaded
# 1.15 Mini lecture – 8 is downloaded
# 1.16 Mini lecture – 9 is downloaded
# 1.17 Mini lecture – 10 is downloaded
# 1.18 Mini lecture – 11 is downloaded
# 1.23 Topic summary is downloaded
# 2.4 Mini lecture – 1 is downloaded
# 2.6 Mini lecture – 2 is downloaded
# 2.9 Mini lecture – 3 is downloaded
# 2.11 Mini lecture – 4 is downloaded
# 2.14 Mini lecture – 5 is downloaded
# 2.16 Mini lecture – 6 is downloaded
# 2.17 Mini lecture – 7 is downloaded
# 2.21 Topic summary is downloaded
# 3.4 Mini lecture – 1 is downloaded
# 3.5 Mini lecture – 2 is downloaded
# 3.7 Mini lecture – 3 is downloaded
# 3.9 Mini lecture – 4 is downloaded
# 3.11 Mini lecture – 5 is downloaded
# 3.12 Mini lecture – 6 is downloaded
# 3.13 Mini lecture – 7 is downloaded
# 3.14 Mini lecture – 8 is downloaded
# 3.22 Topic summary is downloaded
# 4.4 Mini lecture – 1 is downloaded
# 4.7 Mini lecture – 2 is downloaded
# 4.10 Mini lecture – 3 is downloaded
# 4.12 Mini lecture – 4 is downloaded
# 4.15 Mini lecture – 5 is downloaded
# 4.16 Mini lecture – 6 is downloaded
# 4.17 Mini lecture – 7 is downloaded
# 4.19 Topic summary is downloaded
# 5.4 Mini lecture – 1 is downloaded
# 5.5 Mini lecture – 2 is downloaded
# 5.6 Mini lecture – 3 is downloaded
# 5.7 Mini lecture – 4 is downloaded
# 5.18 Topic summary is downloaded
# 6.4 Mini lecture – 1 is downloaded
# 6.6 Mini lecture – 2 is downloaded
# 6.7 Mini lecture – 3 is downloaded
# 6.9 Mini lecture – 4 is downloaded
# 6.11 Mini lecture – 5 is downloaded
# 6.12 Mini lecture – 6 is downloaded
# 6.15 Topic summary is downloaded
# 7.6 Mini lecture – 1 is downloaded
# 8.3 Mini lecture - 1 is downloaded
# 9.5 Mini lecture – 1 is downloaded
# 9.7 Mini lecture – 2 is downloaded
# 10.4 Mini lecture – 1 is downloaded
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-e13adf96eba1> in <module>
#       4 video_base='dr3vr6j2erh62'
#       5
# ----> 6 get_video(login,pw,url,video_base)
#
# <ipython-input-16-6d098f7e011a> in get_video(login, pw, url, video_base)
#      45             lecture_content=BeautifulSoup(lecture_content,'lxml')
#      46
# ---> 47             video_link=re.search(pattern,lecture_content.text).group(0)
#      48             #clean and edit the link
#      49             video_link=video_link.replace('rss','mp4')
#
# AttributeError: 'NoneType' object has no attribute 'group'
